# %%
import pandas as pd
from datetime import datetime

# %%
dados = pd.read_csv('../1_bases_originais/futebol (1).csv', sep=';', encoding='UTF-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\OneDrive - GKS NEGOCIOS SUSTENTAVEIS LTDA EPP\Faculdade\2.Semestre\Web_Data_Applications\AC3_WEBDATA_STREAMLIT\5_scripts\tratamento_base (1).ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive%20-%20GKS%20NEGOCIOS%20SUSTENTAVEIS%20LTDA%20EPP/Faculdade/2.Semestre/Web_Data_Applications/AC3_WEBDATA_STREAMLIT/5_scripts/tratamento_base%20%281%29.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> dados = pd.read_csv('../1_bases_originais/futebol (1).csv', sep=';', encoding='UTF-8')
#
# NameError: name 'pd' is not defined

# %%
dados.columns = dados.columns.str.lower()
dados.columns = dados.columns.str.replace('\W', '')
dados.home_team_name=dados.home_team_name.str.replace('\W','')
dados.away_team_name=dados.away_team_name.str.replace('\W','')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5188\2775261048.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dados.columns = dados.columns.str.replace('\W', '')
# C:\Users\user\AppData\Local\Temp\ipykernel_5188\2775261048.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   dados.home_team_name=dados.home_team_name.str.replace('\W','')
# C:\Users\user\AppData\Local\Temp\ipykernel_5188\2775261048.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   dados.away_team_name=dados.away_team_name.str.replace('\W','')

# %%
dados.head(3)
# Out:
#                 date_gmt    status  attendance home_team_name away_team_name  \
# 0  Apr 16 2021 - 10:00pm  complete         NaN       Guaireña        Olimpia
# 1   Oct 26 2019 - 2:00pm  complete     14008.0       Millwall      StokeCity
# 2   Apr 03 2013 - 4:30pm  complete     25258.0      Sampdoria     InterMilan
#
#                           referee  gameweek  prematchppghome  prematchppgaway  \
# 0  Julio César Quintana Rodríguez      12.0             2.20             2.40
# 1                  Darren England      14.0             1.83             0.67
# 2                      Luca Banti      29.0             1.64             1.57
#
#    home_ppg  away_ppg  home_team_goal_count  away_team_goal_count  \
# 0      1.30      2.10                     1                     2
# 1      1.65      0.87                     2                     0
# 2      1.42      1.37                     0                     2
#
#    total_goal_count  total_goals_at_half_time
# 0                 3                         3
# 1                 2                         1
# 2                 2                         1

# %%
dados.date_gmt.loc[0]
# Out:
# 'Apr 16 2021 - 10:00pm'

# %%
type(dados.date_gmt.loc[0])
# Out:
# str

# %%
dados['date_gmt'] = dados.date_gmt.replace({"-":''})

# %%
dados['datanova'] = pd.to_datetime(dados['date_gmt'])

# %%
dados['ano']=pd.DatetimeIndex(dados['datanova']).year
dados['mes']=pd.DatetimeIndex(dados['datanova']).month

# %%
dados['anomes']=dados['ano'].astype(str) + dados['mes'].astype(str)
dados.loc[dados.mes<10, 'anomes']=dados['ano'].astype(str) +'0'+ dados['mes'].astype(str)
dados.anomes
# Out:
# 0        202104
# 1        201910
# 2        201304
# 3        201712
# 4        201811
#           ...
# 56580    201908
# 56581    201603
# 56582    201312
# 56583    201306
# 56584    201903
# Name: anomes, Length: 56585, dtype: object

# %%
dados.iloc[:,:].head(3)
# Out:
#                 date_gmt    status  attendance home_team_name away_team_name  \
# 0  Apr 16 2021 - 10:00pm  complete         NaN       Guaireña        Olimpia
# 1   Oct 26 2019 - 2:00pm  complete     14008.0       Millwall      StokeCity
# 2   Apr 03 2013 - 4:30pm  complete     25258.0      Sampdoria     InterMilan
#
#                           referee  gameweek  prematchppghome  prematchppgaway  \
# 0  Julio César Quintana Rodríguez      12.0             2.20             2.40
# 1                  Darren England      14.0             1.83             0.67
# 2                      Luca Banti      29.0             1.64             1.57
#
#    home_ppg  away_ppg  home_team_goal_count  away_team_goal_count  \
# 0      1.30      2.10                     1                     2
# 1      1.65      0.87                     2                     0
# 2      1.42      1.37                     0                     2
#
#    total_goal_count  total_goals_at_half_time            datanova   ano  mes  \
# 0                 3                         3 2021-04-16 22:00:00  2021    4
# 1                 2                         1 2019-10-26 14:00:00  2019   10
# 2                 2                         1 2013-04-03 16:30:00  2013    4
#
#    anomes
# 0  202104
# 1  201910
# 2  201304

# %%
dados = dados.replace({'á':'a','ã':'a', 'â':'a', 'í':'i',
                '\W':'_',
                'ÅŸ':'s',
                'Ä°':'I',
                'Ä±':'i',
                'Ã¶':'o',
                'Ã§':'c',
                'ÄŸ':'g',
                'Ã¼':'u',
                'Ã©':'e',
                'Ã¡':'a',
                'Ã³':'o',
                'Ã±':'nh',
                '&':'',
                'Ã…Ë†':'n',
                'Ã§':'c',
                ' ':'',
                'Ã­':'i',
                'Ã£':'a',
                'Ãº':'u',
                'Ã':'a',
                'Ãª':'e',
                'Ã‘':'N',
                'aÂ¢':'a',
                'aÂª':'e',
                'aÂ':'a',
                "á":"a",
                "é":"e",
                "í":"i",
                "ó":"o",
                "ú":"u",
                "ã":"a",
                "õ":"o",
                "aª":"e",
                "á":"a",
                "é":"e",
                "í":"i",
                "ó":"o",
                "ú":"u",
                "ã":"a",
                "õ":"o",
                "ê":"e",
                "â":"a",
                "ô":"o",
                "ê":"e",
                "â":"a",
                "ô":"o"

              }, regex=True)

# %%
dados.head(3)
# Out:
#                 date_gmt    status  attendance home_team_name away_team_name  \
# 0  Apr_16_2021___10_00pm  complete         NaN       Guaireña        Olimpia
# 1   Oct_26_2019___2_00pm  complete     14008.0       Millwall      StokeCity
# 2   Apr_03_2013___4_30pm  complete     25258.0      Sampdoria     InterMilan
#
#                           referee  gameweek  prematchppghome  prematchppgaway  \
# 0  Julio_Cesar_Quintana_Rodriguez      12.0             2.20             2.40
# 1                  Darren_England      14.0             1.83             0.67
# 2                      Luca_Banti      29.0             1.64             1.57
#
#    home_ppg  away_ppg  home_team_goal_count  away_team_goal_count  \
# 0      1.30      2.10                     1                     2
# 1      1.65      0.87                     2                     0
# 2      1.42      1.37                     0                     2
#
#    total_goal_count  total_goals_at_half_time            datanova   ano  mes  \
# 0                 3                         3 2021-04-16 22:00:00  2021    4
# 1                 2                         1 2019-10-26 14:00:00  2019   10
# 2                 2                         1 2013-04-03 16:30:00  2013    4
#
#    anomes
# 0  202104
# 1  201910
# 2  201304

# %%
dados.isnull().sum()
# Out:
# date_gmt                        0
# status                          0
# attendance                  22536
# home_team_name                  0
# away_team_name                  0
# referee                     26348
# gameweek                    12015
# prematchppghome                 0
# prematchppgaway                 0
# home_ppg                        0
# away_ppg                        0
# home_team_goal_count            0
# away_team_goal_count            0
# total_goal_count                0
# total_goals_at_half_time        0
# datanova                        0
# ano                             0
# mes                             0
# anomes                          0
# dtype: int64

# %%
dados.fillna(0, inplace=True)

# %%
dados.to_csv('../2_bases_tratadas/futebol2.csv', sep=';', index=False)

# %%
dados.groupby(by=['datanova', 'home_team_name'])['home_team_goal_count'].sum().reset_index()
# Out:
#                  datanova     home_team_name  home_team_goal_count
# 0     2010-06-29 17:00:00      FCSantaColoma                     0
# 1     2010-06-30 18:30:00           TreFiori                     0
# 2     2010-07-06 16:00:00         Birkirkara                     4
# 3     2010-07-07 16:00:00              Rudar                     4
# 4     2010-07-13 15:00:00          İnterBakı                     0
# ...                   ...                ...                   ...
# 54542 2021-08-02 00:00:00           CSEmelec                     2
# 54543 2021-08-02 00:00:00         LAGalaxyII                     0
# 54544 2021-08-02 00:00:00          Melipilla                     2
# 54545 2021-08-02 01:10:00  JaguaresdeCordoba                     2
# 54546 2021-08-02 18:00:00      VillaEspañola                     1
#
# [54547 rows x 3 columns]

# %%
dados.groupby(by=['home_team_name','datanova'])['home_team_goal_count'].mean().reset_index().rename(columns={'home_team_goal_count':'gols'}).to_csv('../3_bases_upload/gols.csv', sep=';', index=False)

# %% [markdown]
# # Melhorando a visão de gols

# %%
dados.groupby(by=['anomes', 'home_team_name'])['home_team_goal_count'].sum().reset_index()
# Out:
#        anomes      home_team_name  home_team_goal_count
# 0      201006       FCSantaColoma                     0
# 1      201006            TreFiori                     0
# 2      201007                 AIK                     1
# 3      201007                Ajax                     1
# 4      201007              Aktobe                     3
# ...       ...                 ...                   ...
# 28238  202108             Toronto                     1
# 28239  202108              Torque                     0
# 28240  202108    UniversidadChile                     2
# 28241  202108  VancouverWhitecaps                     2
# 28242  202108       VillaEspañola                     1
#
# [28243 rows x 3 columns]

# %%
dados.groupby(by=['home_team_name','anomes'])['home_team_goal_count'].mean().reset_index().rename(columns={'home_team_goal_count':'gols'}).to_csv('../3_bases_upload/gols.csv', sep=';', index=False)

# %% [markdown]
# # Adicionando novos indicadores

# %%
dados.groupby(by=['anomes', 'home_team_name'])['home_team_goal_count', 'home_ppg'].mean().reset_index()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5188\2024526820.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dados.groupby(by=['anomes', 'home_team_name'])['home_team_goal_count', 'home_ppg'].mean().reset_index()
#        anomes      home_team_name  home_team_goal_count  home_ppg
# 0      201006       FCSantaColoma                   0.0      0.00
# 1      201006            TreFiori                   0.0      0.00
# 2      201007                 AIK                   0.5      1.00
# 3      201007                Ajax                   1.0      1.30
# 4      201007              Aktobe                   1.5      1.75
# ...       ...                 ...                   ...       ...
# 28238  202108             Toronto                   1.0      0.88
# 28239  202108              Torque                   0.0      1.50
# 28240  202108    UniversidadChile                   2.0      2.00
# 28241  202108  VancouverWhitecaps                   2.0      0.94
# 28242  202108       VillaEspañola                   1.0      0.58
#
# [28243 rows x 4 columns]

# %%
dados.groupby(by=['anomes', 'home_team_name'])['home_team_goal_count', 'home_ppg'].mean().reset_index().rename(columns={'home_team_goal_count':'gols'}).to_csv('../3_bases_upload/gols.csv', sep=';', index=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5188\1329051740.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dados.groupby(by=['anomes', 'home_team_name'])['home_team_goal_count', 'home_ppg'].mean().reset_index().rename(columns={'home_team_goal_count':'gols'}).to_csv('../3_bases_upload/gols.csv', sep=';', index=False)

# %%
dados.columns
# Out:
# Index(['date_gmt', 'status', 'attendance', 'home_team_name', 'away_team_name',
#        'referee', 'gameweek', 'prematchppghome', 'prematchppgaway', 'home_ppg',
#        'away_ppg', 'home_team_goal_count', 'away_team_goal_count',
#        'total_goal_count', 'total_goals_at_half_time', 'datanova', 'ano',
#        'mes', 'anomes'],
#       dtype='object')
